# %%
import requests
import os
from bs4 import BeautifulSoup

# %%
url='https://www.nykaa.com/minimalist-2percent-salicylic-acid-lha-face-cleanser-for-oil-control-acne/reviews/1467106?skuId=1467106&ptype=reviews'

# %%
! pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\ashwin\anaconda3\lib\site-packages (4.8.0)

# %%
data=requests.get(url).text

# %%
data
# Out:
# '<!doctype html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=5.0"/><meta name="theme-color" content="#fff"/><meta name="author" content="NykaaFrontendTeam"/><link rel="icon" href="//images-static.nykaa.com/media/favicon/default/nykaa_favicon_a.png" type="image/x-icon"/><link rel="canonical" href="https://www.nykaa.com/minimalist-2percent-salicylic-acid-lha-face-cleanser-for-oil-control-acne/reviews/1467106"/><title data-react-helmet="true">Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online at Best Price in India | Nykaa</title><meta data-react-helmet="true" property="og:title" content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online at Best Price in India | Nykaa"/><meta data-react-helmet="true" property="twitter:title" content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online at Best Price in India | Nykaa"/><meta data-react-helmet="true" name="description" content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne at best price from Nykaa. Check out Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne review. ✓COD ✓Free Shipping"/><meta data-react-helmet="true" name="og:description" content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne at best price from Nykaa. Check out Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne review. ✓COD ✓Free Shipping"/><meta data-react-helmet="true" name="twitter:description" content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne at best price from Nykaa. Check out Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne review. ✓COD ✓Free Shipping"/><meta data-react-helmet="true" name="keywords" content="Minimalist 2% Salicylic Acid + Lha Face Cleanser For Oil Control &amp; Acne, Skin, Cleansers, Cleanser"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" property="twitter:card" content="summary_large_image"/><meta data-react-helmet="true" property="og:site_name" content="Nykaa"/><meta data-react-helmet="true" property="og:url" content="https://www.nykaa.com/minimalist-2percent-salicylic-acid-lha-face-cleanser-for-oil-control-acne/reviews/1467106"/><meta data-react-helmet="true" property="al:android:package" content="com.fsn.nykaa"/><meta data-react-helmet="true" property="al:android:app_name" content="Nykaa: Beauty Shopping App"/><meta data-react-helmet="true" property="al:ios:app_store_id" content="1022363908"/><meta data-react-helmet="true" property="al:ios:app_name" content="Nykaa – Makeup/Beauty Shopping"/><link data-react-helmet="true" rel="preload" as="font" href="//asset.nykaa.com/dstatic/assets/Inter.45cae4a499.woff2" crossorigin=""/><link rel="preconnect" href="//images-static.nykaa.com"/><link rel="preconnect" href="//cdn.nykaa.com"/><link rel="preconnect" href="//cdn.naikaa.com"/><link rel="preconnect" href="//assets.adobedtm.com"/><link rel="preconnect" href="//cdn.speedcurve.com"/><script type="text/javascript">var _nTime = Date.now();window.NYKAA_WEB_INTERFACE = {}</script><script type="text/javascript">\n            LUX=(function(){var a=("undefined"!==typeof(LUX)&&" ...

# %%
soup=BeautifulSoup(data,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1.0,maximum-scale=5.0" name="viewport"/><meta content="#fff" name="theme-color"/><meta content="NykaaFrontendTeam" name="author"/><link href="//images-static.nykaa.com/media/favicon/default/nykaa_favicon_a.png" rel="icon" type="image/x-icon"/><link href="https://www.nykaa.com/minimalist-2percent-salicylic-acid-lha-face-cleanser-for-oil-control-acne/reviews/1467106" rel="canonical"/><title data-react-helmet="true">Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online at Best Price in India | Nykaa</title><meta content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online at Best Price in India | Nykaa" data-react-helmet="true" property="og:title"/><meta content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online at Best Price in India | Nykaa" data-react-helmet="true" property="twitter:title"/><meta content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne at best price from Nykaa. Check out Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne review. ✓COD ✓Free Shipping" data-react-helmet="true" name="description"/><meta content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne at best price from Nykaa. Check out Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne review. ✓COD ✓Free Shipping" data-react-helmet="true" name="og:description"/><meta content="Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne Online: Buy Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne at best price from Nykaa. Check out Minimalist 2% Salicylic Acid + LHA Face Wash With Zinc For Reducing Sebum &amp; Acne review. ✓COD ✓Free Shipping" data-react-helmet="true" name="twitter:description"/><meta content="Minimalist 2% Salicylic Acid + Lha Face Cleanser For Oil Control &amp; Acne, Skin, Cleansers, Cleanser" data-react-helmet="true" name="keywords"/><meta content="website" data-react-helmet="true" property="og:type"/><meta content="summary_large_image" data-react-helmet="true" property="twitter:card"/><meta content="Nykaa" data-react-helmet="true" property="og:site_name"/><meta content="https://www.nykaa.com/minimalist-2percent-salicylic-acid-lha-face-cleanser-for-oil-control-acne/reviews/1467106" data-react-helmet="true" property="og:url"/><meta content="com.fsn.nykaa" data-react-helmet="true" property="al:android:package"/><meta content="Nykaa: Beauty Shopping App" data-react-helmet="true" property="al:android:app_name"/><meta content="1022363908" data-react-helmet="true" property="al:ios:app_store_id"/><meta content="Nykaa – Makeup/Beauty Shopping" data-react-helmet="true" property="al:ios:app_name"/><link as="font" crossorigin="" data-react-helmet="true" href="//asset.nykaa.com/dstatic/assets/Inter.45cae4a499.woff2" rel="preload"/><link href="//images-static.nykaa.com" rel="preconnect"/><link href="//cdn.nykaa.com" rel="preconnect"/><link href="//cdn.naikaa.com" rel="preconnect"/><link href="//assets.adobedtm.com" rel="preconnect"/><link href="//cdn.speedcurve.com" rel="preconnect"/><script type="text/javascript">var _nTime = Date.now();window.NYKAA_WEB_INTERFACE = {}</script><script type="text/javascript">
#             LUX=(function(){var a=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMarks)?LUX.gaMarks:[]);var d=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMeasures)?LUX.gaMeasures:[]);var j="LUX_start";var k=window.performance;var l=("undefined"!==typeof(LUX)&&LUX.ns?LUX.ns:(Date.now?Date.now():+(new Date())));if(k&&k.timing&&k.timing.navigationStart){l=k.timing.navigationStart}function f(){if(k&&k.now){return k.now()}var o=Date.now?Date.now():+(new Date());return o-l}function b(n){if(k){if(k.mark){return k.mark(n)}else{if(k.webkitMark){return k.webkitMark(n)}}}a.push({name:n,entryType:"mark",startTime:f(),duration:0});return}function m(p,t,n){if("undefined"===typeof(t)&&h(j)){t=j}if(k){if(k.measure){if(t){if(n){return k.measure(p,t,n)}else{return k.measure(p,t)}}else{return k.measure(p)}}else{if(k.webkitMeasure){return k.webkitMeasure(p,t,n)}}}var r=0,o=f();if(t){var s=h(t);if(s){r=s.startTime}else{if(k&&k.timing&&k.timing[t]){r=k.timing[t]-k.timing.navigationStart}else{return}}}if(n){var q=h(n);if(q){o=q.startTime}else{if(k&&k.timing&&k.timing[n]){o=k.timing[n]-k.timing.navigationStart}else{return}}}d.push({name:p,entryType:"measure",startTime:r,duration:(o-r)});return}function h(n){return c(n,g())}function c(p,o){for(i=o.length-1;i>=0;i--){var n=o[i];if(p===n.name){return n}}return undefined}function g(){if(k){if(k.getEntriesByType){return k.getEntriesByType("mark")}else{if(k.webkitGetEntriesByType){return k.webkitGetEntriesByType("mark")}}}return a}return{mark:b,measure:m,gaMarks:a,gaMeasures:d}})();LUX.ns=(Date.now?Date.now():+(new Date()));LUX.ac=[];LUX.cmd=function(a){LUX.ac.push(a)};LUX.init=function(){LUX.cmd(["init"])};LUX.send=function(){LUX.cmd(["send"])};LUX.addData=function(a,b){LUX.cmd(["addData",a,b])};LUX_ae=[];window.addEventListener("error",function(a){LUX_ae.push(a)});LUX_al=[];if("function"===typeof(PerformanceObserver)&&"function"===typeof(PerformanceLongTaskTiming)){var LongTaskObserver=new PerformanceObserver(function(c){var b=c.getEntries();for(var a=0;a<b.length;a++){var d=b[a];LUX_al.push(d)}});try{LongTaskObserver.observe({type:["longtask"]})}catch(e){}};
#           </script><script async="" crossorigin="anonymous" defer="" src="https://cdn.speedcurve.com/js/lux.js?id=594338388"></script></head><body><div id="app"><style data-emotion-css="1rb0eh6">html{line-height:1.15;-webkit-text-size-adjust:100%;}body{margin:0;}main{display:block;}h1{font-size:2em;margin:0.67em 0;}hr{box-sizing:content-box;height:0;overflow:visible;}pre{font-family:monospace,monospace;font-size:1em;}a{background-color:transparent;}abbr[title]{border-bottom:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted;}b,strong{font-weight:bolder;}code,kbd,samp{font-family:monospace,monospace;font-size:1em;}small{font-size:80%;}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;}sub{bottom:-0.25em;}sup{top:-0.5em;}img{border-style:none;}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0;}button,input{overflow:visible;}button,select{text-transform:none;}button,[type="button"],[type="reset"],[type="submit"]{-webkit-appearance:button;}button::-moz-focus-inner,[type="button"]::-moz-focus-inner,[type="reset"]::-moz-focus-inner,[type="submit"]::-moz-focus-inner{border-style:none;padding:0;}button:-moz-focusring,[type="button"]:-moz-focusring,[type="reset"]:-moz-focusring,[type="submit"]:-moz-focusring{outline:1px dotted ButtonText;}fieldset{padding:0.35em 0.75em 0.625em;}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal;}progress{vertical-align:baseline;}textarea{overflow:auto;}[type="checkbox"],[type="radio"]{box-sizing:border-box;padding:0;}[type="number"]::-webkit-inner-spin-button,[type="number"]::-webkit-outer-spin-button{height:auto;}[type="search"]{-webkit-appearance:textfield;outline-offset:-2px;}[type="search"]::-webkit-search-decoration{-webkit-appearance:none;}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit;}details{display:block;}summary{display:list-item;}template{display:none;}[hidden]{display:none;}*{margin:0;padding:0;box-sizing:border-box;-webkit-tap-highlight-color:transparent;}@font-face{font-family:"Source Sans Pro";src:url("//asset.nykaa.com/dstatic/assets/ssp-l.fbefd76e82.woff2") format("woff2");font-weight:400;font-style:normal;font-display:swap;}@font-face{font-family:"Source Sans Pro";src:url("//asset.nykaa.com/dstatic/assets/ssp-m.7b255a3782.woff2") format("woff2");font-weight:500;font-style:normal;font-display:swap;}@font-face{font-family:"Source Sans Pro";src:url("//asset.nykaa.com/dstatic/assets/ssp-b.e487d5cf73.woff2") format("woff2");font-weight:600;font-style:normal;font-display:swap;}@font-face{font-family:"Inter";src:url("//asset.nykaa.com/dstatic/assets/Inter.45cae4a499.woff2") format("woff2");font-weight:400;font-style:normal;font-display:swap;}@font-face{font-family:"Inter";src:url("//asset.nykaa.com/dstatic/assets/Inter.45cae4a499.woff2") format("woff2");font-weight:500;font-style:normal;font-display:swap;}@font-face{font-family:"Inter";src:url("//asset.nykaa.com/dstatic/assets/Inter.45cae4a499.woff2") format("woff2");font-weight:600;font-style:normal;font-display:swap;}body{font-family:"Inter",Roboto,Arial,sans-serif;background-color:#f3f3f3;font-size:14px;line-height:1;}body.overflow-hidden{overflow:hidden;}:focus{outline:0;}ol,ul{list-style:none;}</style><style data-emotion-css="bxqdqd">.css-bxqdqd{position:relative;height:162px;}</style><header class="css-bxqdqd e1e0j9zy0"><style data-emotion-css="1qef9x9">.css-1qef9x9{background:#fff;position:fixed;z-index:10;box-shadow:0 2px 3px 0 rgba(0,0,0,0.1);width:100%;left:0;right:0;}</style><div class="css-1qef9x9 e1e0j9zy1" id="header_id"><style data-emotion-css="be2ift">.css-be2ift{height:40px;}</style><div class="css-be2ift"></div><style data-emotion-css="uhagyq">.css-uhagyq{border-bottom:solid 1px #e6dede;width:100%;}</style><div class="css-uhagyq e1e0j9zy3"><style data-emotion-css="2o3va">.css-2o3va{padding-t ...
# </p></section><div class="lazy-load-wrap"><div class="css-1uik25e"></div></div><section class="css-1cs7f2q"><span class="reviewLikeButton css-1bypssd"><svg height="21" viewbox="0 0 22 21" width="22" xmlns="http://www.w3.org/2000/svg"><title>thumb</title><g fill="none" fill-rule="evenodd" stroke="#FC2779" stroke-width=".8"><path d="M.934 9.09l5.361-.085a.3.3 0 01.305.3v10.87a.3.3 0 01-.3.3H2.283a.3.3 0 01-.298-.262L.641 9.428a.3.3 0 01.293-.337z"></path><path d="M6.6 11.883l3.377-6.799V1.468c1.039-.36 1.987.153 2.845 1.538.859 1.385.698 3.383-.482 5.994h7.897c.863-.003 1.294.429 1.294 1.294 0 .866-.657 1.396-1.973 1.59.99-.084 1.486.377 1.486 1.382 0 1.006-.72 1.52-2.162 1.543 1.064.045 1.596.46 1.596 1.243 0 .784-.78 1.308-2.338 1.572.942.125 1.413.6 1.413 1.425 0 .825-.475 1.3-1.427 1.427-5.74-.087-8.889-.13-9.444-.13-.321 0-.321-.961-.803-.961H6.595l.005-7.502z" stroke-linecap="round" stroke-linejoin="round"></path></g></svg><div class="css-18su9bk">Helpful</div></span><section class="css-tkdkid"><strong class="css-137iujl">15</strong>people found this helpful</section></section></div></div><div class="css-apl1oj"><div class="css-j7tqxv"><div class="userInfoSection css-10ljiw7"><img alt="avatar" class="css-cyn3qf" src="https://images-static.nykaa.com/prod-review/default_profile_image.png"/><div class="css-1fk3xnz"><span class="css-amd8cf">Reshma Sarkar</span><span class="css-1w1bueb"><i class="css-16fzara"><svg height="13" width="13" xmlns="http://www.w3.org/2000/svg"><title>right icon</title><g fill="none" fill-rule="evenodd"><circle cx="6.5" cy="6.5" fill="#FFD3E4" r="6.5"></circle><path d="M9.087 3.852L5.547 7.36l-.21.003-1.37-1.294-1.024 1.074 2.525 2.385 4.67-4.627-1.051-1.05z" fill="#FF5295" fill-rule="nonzero" stroke="#FFD3E4" stroke-width=".3"></path></g></svg></i>Verified Buyers</span></div></div></div><div class="css-ggpltb"><div class="css-10z6eaz"><section class="css-rwwnk2"><span class="css-1at2wjx">5<i class="css-w0v4um"><svg height="14" width="13" xmlns="http://www.w3.org/2000/svg"><title>star</title><path d="M2.555 11.878c-.05 0-.1-.025-.15-.05a.277.277 0 01-.1-.275l1.098-4.092L.109 4.79c-.1-.05-.125-.175-.1-.275a.24.24 0 01.225-.174l4.242-.225L5.998.15c.05-.075.15-.15.25-.15s.2.075.225.15l1.522 3.967 4.242.225c.1 0 .2.075.225.174.025.1 0 .2-.075.275L9.093 7.46l1.098 4.092c.025.1 0 .2-.1.275-.075.05-.2.075-.274 0L6.248 9.532l-3.569 2.296c-.05.05-.075.05-.124.05z" fill="#FFF"></path></svg></i></span></section><div class="css-177e1lt">21/01/2022</div></div><section class="css-1v6g5ho"><h4 class="css-tm4hnq">"<!-- -->Loved it !!<!-- -->"</h4><p class="css-1n0nrdk">Cleanses very nicely !! </p></section><div class="lazy-load-wrap"><div class="css-1uik25e"></div></div><section class="css-1cs7f2q"><span class="reviewLikeButton css-1bypssd"><svg height="21" viewbox="0 0 22 21" width="22" xmlns="http://www.w3.org/2000/svg"><title>thumb</title><g fill="none" fill-rule="evenodd" stroke="#FC2779" stroke-width=".8"><path d="M.934 9.09l5.361-.085a.3.3 0 01.305.3v10.87a.3.3 0 01-.3.3H2.283a.3.3 0 01-.298-.262L.641 9.428a.3.3 0 01.293-.337z"></path><path d="M6.6 11.883l3.377-6.799V1.468c1.039-.36 1.987.153 2.845 1.538.859 1.385.698 3.383-.482 5.994h7.897c.863-.003 1.294.429 1.294 1.294 0 .866-.657 1.396-1.973 1.59.99-.084 1.486.377 1.486 1.382 0 1.006-.72 1.52-2.162 1.543 1.064.045 1.596.46 1.596 1.243 0 .784-.78 1.308-2.338 1.572.942.125 1.413.6 1.413 1.425 0 .825-.475 1.3-1.427 1.427-5.74-.087-8.889-.13-9.444-.13-.321 0-.321-.961-.803-.961H6.595l.005-7.502z" stroke-linecap="round" stroke-linejoin="round"></path></g></svg><div class="css-18su9bk">Helpful</div></span><section class="css-tkdkid"><strong class="css-137iujl">12</strong>people found this helpful</section></section></div></div><div class="css-apl1oj"><div class="css-j7tqxv"><div class="userInfoSection css-10ljiw7"><img alt="avatar" class="css-cyn3qf" src="https://images-static.nykaa.com/prod-review/default_profile_image.png"/><div class="css-1fk3xnz"><span class= ...
# </p></section><div class="lazy-load-wrap"><div class="css-1uik25e"></div></div><section class="css-1cs7f2q"><span class="reviewLikeButton css-1bypssd"><svg height="21" viewbox="0 0 22 21" width="22" xmlns="http://www.w3.org/2000/svg"><title>thumb</title><g fill="none" fill-rule="evenodd" stroke="#FC2779" stroke-width=".8"><path d="M.934 9.09l5.361-.085a.3.3 0 01.305.3v10.87a.3.3 0 01-.3.3H2.283a.3.3 0 01-.298-.262L.641 9.428a.3.3 0 01.293-.337z"></path><path d="M6.6 11.883l3.377-6.799V1.468c1.039-.36 1.987.153 2.845 1.538.859 1.385.698 3.383-.482 5.994h7.897c.863-.003 1.294.429 1.294 1.294 0 .866-.657 1.396-1.973 1.59.99-.084 1.486.377 1.486 1.382 0 1.006-.72 1.52-2.162 1.543 1.064.045 1.596.46 1.596 1.243 0 .784-.78 1.308-2.338 1.572.942.125 1.413.6 1.413 1.425 0 .825-.475 1.3-1.427 1.427-5.74-.087-8.889-.13-9.444-.13-.321 0-.321-.961-.803-.961H6.595l.005-7.502z" stroke-linecap="round" stroke-linejoin="round"></path></g></svg><div class="css-18su9bk">Helpful</div></span><section class="css-tkdkid"><strong class="css-137iujl">5</strong>people found this helpful</section></section></div></div><div class="css-apl1oj"><div class="css-j7tqxv"><div class="userInfoSection css-10ljiw7"><img alt="avatar" class="css-cyn3qf" src="https://images-static.nykaa.com/prod-review/default_profile_image.png"/><div class="css-1fk3xnz"><span class="css-amd8cf">Sesha</span><span class="css-1w1bueb"><i class="css-16fzara"><svg height="13" width="13" xmlns="http://www.w3.org/2000/svg"><title>right icon</title><g fill="none" fill-rule="evenodd"><circle cx="6.5" cy="6.5" fill="#FFD3E4" r="6.5"></circle><path d="M9.087 3.852L5.547 7.36l-.21.003-1.37-1.294-1.024 1.074 2.525 2.385 4.67-4.627-1.051-1.05z" fill="#FF5295" fill-rule="nonzero" stroke="#FFD3E4" stroke-width=".3"></path></g></svg></i>Verified Buyers</span></div></div></div><div class="css-ggpltb"><div class="css-10z6eaz"><section class="css-rwwnk2"><span class="css-1at2wjx">5<i class="css-w0v4um"><svg height="14" width="13" xmlns="http://www.w3.org/2000/svg"><title>star</title><path d="M2.555 11.878c-.05 0-.1-.025-.15-.05a.277.277 0 01-.1-.275l1.098-4.092L.109 4.79c-.1-.05-.125-.175-.1-.275a.24.24 0 01.225-.174l4.242-.225L5.998.15c.05-.075.15-.15.25-.15s.2.075.225.15l1.522 3.967 4.242.225c.1 0 .2.075.225.174.025.1 0 .2-.075.275L9.093 7.46l1.098 4.092c.025.1 0 .2-.1.275-.075.05-.2.075-.274 0L6.248 9.532l-3.569 2.296c-.05.05-.075.05-.124.05z" fill="#FFF"></path></svg></i></span></section><div class="css-177e1lt">30/05/2022</div></div><section class="css-1v6g5ho"><h4 class="css-tm4hnq">"<!-- -->Amazing product! Keeps acne under control<!-- -->"</h4><p class="css-1n0nrdk">Pictures say it all! I'm using this face wash since October 2021, I also use minimalist niacinamide serum for my acne marks and both these products work really well on my ski<strong>...Read More</strong></p></section><div class="lazy-load-wrap"><div class="css-1uik25e"></div></div><section class="css-1cs7f2q"><span class="reviewLikeButton css-1bypssd"><svg height="21" viewbox="0 0 22 21" width="22" xmlns="http://www.w3.org/2000/svg"><title>thumb</title><g fill="none" fill-rule="evenodd" stroke="#FC2779" stroke-width=".8"><path d="M.934 9.09l5.361-.085a.3.3 0 01.305.3v10.87a.3.3 0 01-.3.3H2.283a.3.3 0 01-.298-.262L.641 9.428a.3.3 0 01.293-.337z"></path><path d="M6.6 11.883l3.377-6.799V1.468c1.039-.36 1.987.153 2.845 1.538.859 1.385.698 3.383-.482 5.994h7.897c.863-.003 1.294.429 1.294 1.294 0 .866-.657 1.396-1.973 1.59.99-.084 1.486.377 1.486 1.382 0 1.006-.72 1.52-2.162 1.543 1.064.045 1.596.46 1.596 1.243 0 .784-.78 1.308-2.338 1.572.942.125 1.413.6 1.413 1.425 0 .825-.475 1.3-1.427 1.427-5.74-.087-8.889-.13-9.444-.13-.321 0-.321-.961-.803-.961H6.595l.005-7.502z" stroke-linecap="round" stroke-linejoin="round"></path></g></svg><div class="css-18su9bk">Helpful</div></span><section class="css-tkdkid"><strong class="css-137iujl">136</strong>people found this helpful</section></section></div></div><div class="css-apl1oj"><div class="css ...
# And I have also uploaded the new version.</p></section><div class="lazy-load-wrap"><div class="css-1uik25e"></div></div><section class="css-1cs7f2q"><span class="reviewLikeButton css-1bypssd"><svg height="21" viewbox="0 0 22 21" width="22" xmlns="http://www.w3.org/2000/svg"><title>thumb</title><g fill="none" fill-rule="evenodd" stroke="#FC2779" stroke-width=".8"><path d="M.934 9.09l5.361-.085a.3.3 0 01.305.3v10.87a.3.3 0 01-.3.3H2.283a.3.3 0 01-.298-.262L.641 9.428a.3.3 0 01.293-.337z"></path><path d="M6.6 11.883l3.377-6.799V1.468c1.039-.36 1.987.153 2.845 1.538.859 1.385.698 3.383-.482 5.994h7.897c.863-.003 1.294.429 1.294 1.294 0 .866-.657 1.396-1.973 1.59.99-.084 1.486.377 1.486 1.382 0 1.006-.72 1.52-2.162 1.543 1.064.045 1.596.46 1.596 1.243 0 .784-.78 1.308-2.338 1.572.942.125 1.413.6 1.413 1.425 0 .825-.475 1.3-1.427 1.427-5.74-.087-8.889-.13-9.444-.13-.321 0-.321-.961-.803-.961H6.595l.005-7.502z" stroke-linecap="round" stroke-linejoin="round"></path></g></svg><div class="css-18su9bk">Helpful</div></span><section class="css-tkdkid"><strong class="css-137iujl">9</strong>people found this helpful</section></section></div></div><div class="css-apl1oj"><div class="css-j7tqxv"><div class="userInfoSection css-10ljiw7"><img alt="avatar" class="css-cyn3qf" src="https://images-static.nykaa.com/prod-review/default_profile_image.png"/><div class="css-1fk3xnz"><span class="css-amd8cf">Jagjot Jaura</span><span class="css-1w1bueb"><i class="css-16fzara"><svg height="13" width="13" xmlns="http://www.w3.org/2000/svg"><title>right icon</title><g fill="none" fill-rule="evenodd"><circle cx="6.5" cy="6.5" fill="#FFD3E4" r="6.5"></circle><path d="M9.087 3.852L5.547 7.36l-.21.003-1.37-1.294-1.024 1.074 2.525 2.385 4.67-4.627-1.051-1.05z" fill="#FF5295" fill-rule="nonzero" stroke="#FFD3E4" stroke-width=".3"></path></g></svg></i>Verified Buyers</span></div></div></div><div class="css-ggpltb"><div class="css-10z6eaz"><section class="css-rwwnk2"><span class="css-1at2wjx">5<i class="css-w0v4um"><svg height="14" width="13" xmlns="http://www.w3.org/2000/svg"><title>star</title><path d="M2.555 11.878c-.05 0-.1-.025-.15-.05a.277.277 0 01-.1-.275l1.098-4.092L.109 4.79c-.1-.05-.125-.175-.1-.275a.24.24 0 01.225-.174l4.242-.225L5.998.15c.05-.075.15-.15.25-.15s.2.075.225.15l1.522 3.967 4.242.225c.1 0 .2.075.225.174.025.1 0 .2-.075.275L9.093 7.46l1.098 4.092c.025.1 0 .2-.1.275-.075.05-.2.075-.274 0L6.248 9.532l-3.569 2.296c-.05.05-.075.05-.124.05z" fill="#FFF"></path></svg></i></span></section><div class="css-177e1lt">21/09/2021</div></div><section class="css-1v6g5ho"><h4 class="css-tm4hnq">"<!-- -->Best product ❤️<!-- -->"</h4><p class="css-1n0nrdk">Now i have used all the minimalist products they all are amazing 💯❤️ Best for the oily acne prone skin 💖make your skin glowing and bright without any pimple and breakouts😍</p></section><div class="lazy-load-wrap"><div class="css-1uik25e"></div></div><section class="css-1cs7f2q"><span class="reviewLikeButton css-1bypssd"><svg height="21" viewbox="0 0 22 21" width="22" xmlns="http://www.w3.org/2000/svg"><title>thumb</title><g fill="none" fill-rule="evenodd" stroke="#FC2779" stroke-width=".8"><path d="M.934 9.09l5.361-.085a.3.3 0 01.305.3v10.87a.3.3 0 01-.3.3H2.283a.3.3 0 01-.298-.262L.641 9.428a.3.3 0 01.293-.337z"></path><path d="M6.6 11.883l3.377-6.799V1.468c1.039-.36 1.987.153 2.845 1.538.859 1.385.698 3.383-.482 5.994h7.897c.863-.003 1.294.429 1.294 1.294 0 .866-.657 1.396-1.973 1.59.99-.084 1.486.377 1.486 1.382 0 1.006-.72 1.52-2.162 1.543 1.064.045 1.596.46 1.596 1.243 0 .784-.78 1.308-2.338 1.572.942.125 1.413.6 1.413 1.425 0 .825-.475 1.3-1.427 1.427-5.74-.087-8.889-.13-9.444-.13-.321 0-.321-.961-.803-.961H6.595l.005-7.502z" stroke-linecap="round" stroke-linejoin="round"></path></g></svg><div class="css-18su9bk">Helpful</div></span><section class="css-tkdkid"><strong class="css-137iujl">44</strong>people found this helpful</section></section></div></div><div class="css-apl1oj"><div class="css-j7tqxv"><d ...
#           var _nTimeGC;
#           function timingBucket(t1, t2) { var t = t1 - t2; if (t <=200){ t = 200} else if (t <=400){ t = 400} else if (t <=500){ t = 500} else if (t <=1000) {t=1000} else if (t <2000) {t=2000} else if(t < 3000){ t = 3000} else if(t < 4000){ t = 4000} else if(t < 5000){ t = 5000} else if(t < 8000){ t = 8000}; return t };
#           var loadLauch = function() {
#             var _nTimeCall = Date.now(); window.dataLayer = dataLayer || [];
#             dataLayer.push({ event: 'scriptsLoaded', _sl: { category: 'ScriptTiming', action: 'loaded', label: timingBucket(_nTimeGC, _nTime), value: timingBucket(_nTimeCall, _nTime) }});
#             (function(w,d,s){var f=d.getElementsByTagName(s)[0],
#               j=d.createElement(s);j.src=
#               '//assets.adobedtm.com/launch-ENfc71325a95e740318c9e1ddc9d8c0017.min.js';j.async=true;f.parentNode.insertBefore(j,f);
#               })(window,document,'script');
#           };
#           var loadGTM = function() {
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-MWT2MSJ');
#           };
#           var loadGtmCaller = function() {
#             _nTimeGC = Date.now();
#             var effectiveConnectionType = (
#               window.navigator
#               && window.navigator.connection
#               && window.navigator.connection.effectiveType
#             ) ? window.navigator.connection.effectiveType : null;
#
#             // Setting this value in window for future needs.
#             window.isSlowConnection = /(2g)/.test(effectiveConnectionType);
#             var mediumConnection = /(3g)/.test(effectiveConnectionType);
#             // logic to load GTM
#             if (window.isSlowConnection) {
#               // do nothing
#             } else if(mediumConnection) {
#               setTimeout(function() {
#                 loadLauch();
#               }, 2000);
#               setTimeout(function() {
#                 loadGTM();
#               }, 4000);
#             } else {
#               loadLauch();
#               setTimeout(function() {
#                 loadGTM();
#               }, 2500);
#             }
#           }
#
#           if(window.requestIdleCallback) {
#             window.requestIdleCallback(loadGtmCaller)
#           } else {
#             loadGtmCaller();
#           }
#         </script><script type="application/ld+json">{
#           "@context": "http://schema.org",
#           "@type": "Corporation",
#           "name": "Nykaa",
#           "legalName" : "Nykaa E-Retail Private Limited",
#           "description": "Nykaa.com is a premier online beauty and wellness destination. It offers beauty and wellness products for men and women at best prices. The products are 100 percent genuine and authentic, sourced directly from the brands.",
#           "url": "https://www.nykaa.com/",
#           "logo": "https://theme.zdassets.com/theme_assets/222949/60503496e109d9e249ab19791fb335f0459a483e.png",
#           "foundingDate": "April, 2012",
#           "foundingLocation": "Mumbai",
#           "founders": [
#           {
#           "@type": "Person",
#           "name": "Falguni Nayar"
#           } ],
#           "address": {
#           "@type": "PostalAddress",
#           "streetAddress": "#A2, 4th Floor, Cnergy IT Park, Old Standard Mill Compound, Appasaheb Marathe Marg, Prabhadevi",
#           "addressLocality": "Prabhadevi",
#           "addressRegion": "Mumbai",
#           "postalCode": "400025",
#           "addressCountry": "India"
#           },
#           "contactPoint": {
#           "@type": "ContactPoint",
#           "contactType": "customer support",
#           "telephone": "[1800-267-4444]",
#           "email": "support@nykaa.com",
#           "hoursAvailable": "Mon - Sat 09:00 - 21:00"
#           },
#           "sameAs": [
#           "https://en.wikipedia.org/wiki/Nykaa",
#           "https://www.linkedin.com/company/nykaa-com/",
#           "https://www.instagram.com/mynykaa/",
#           "https://www.facebook.com/MyNykaa",
#           "https://www.youtube.com/channel/UCoaH2UtB1PsV7av17woV1BA",
#           "https://twitter.com/MyNykaa",
#           "https://in.pinterest.com/mynykaa/",
#           "https://nykaaonline.tumblr.com/",
#           "https://plus.google.com/+Nykaa",
#           "https://www.wikidata.org/wiki/Q22907412",
#           "https://www.crunchbase.com/organization/nykaa"
#           ]
#         }</script></body></html>

# %%
reviews=soup.find('div',class_='css-17i1bd7 e1767jz00')

# %%
headline=soup.find_all('h4',class_='css-tm4hnq')

# %%
headline
# Out:
# [<h4 class="css-tm4hnq">"<!-- -->Revolution in skin care!! <!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Revolution in skin care!! <!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Good for acne prone skin <!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Good<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Worth it<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Leaves skin loved and nourished <!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Pretty good<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Good product!<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Damn🔥🔥🔥🔥<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Nice<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Packaging<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Loved it !!<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Minimalist 2%Salicylic acid<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Amazing results <!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Salicylic acid<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Amazing product! Keeps acne under control<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Minimalist 2% Salicylic Acid + Lha Face Cleanser For Oil Control &amp; Acne<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Cleanser for acne-prone skin🌸<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Best product ❤️<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Good<!-- -->"</h4>,
#  <h4 class="css-tm4hnq">"<!-- -->Finishing up my second bottle<!-- -->"</h4>]

# %%
tit=[]
for x in headline:
    a=x.text
    tit.append(a)

# %%
tit[:5]
# Out:
# ['"Revolution in skin care!! "',
#  '"Revolution in skin care!! "',
#  '"Good for acne prone skin "',
#  '"Good"',
#  '"Worth it"']

# %%
reviews_all=soup.find_all('p',class_='css-1n0nrdk')
reviews_all[:5]
# Out:
# [<p class="css-1n0nrdk">THE best of the bests I have ever came across to 🙂 This will definitely mark a niche in yhe skincare Industry as the results are beyond expected.  Must buy!!! </p>,
#  <p class="css-1n0nrdk">THE best of the bests I have ever came across to 🙂 This will definitely mark a niche in yhe skincare Industry as the results are beyond expected.  Must buy!!! </p>,
#  <p class="css-1n0nrdk">Loved the quality of this product. Not harsh on skin. Fragrance free. Worth it.</p>,
#  <p class="css-1n0nrdk">A new product I'm very happy with controls the oil and acne. The inner packaging is very cute!</p>,
#  <p class="css-1n0nrdk">Its a good cleanser and mild exfoliator. I am using it since 1 month. It reduces my acne breakout and also keep my skin oil free. Still using it for best result. I also use m<strong>...Read More</strong></p>]

# %%
rev_all=[]
for y in reviews_all:
    b=y.text
    rev_all.append(b)

# %%
rev_all[:5]
# Out:
# ['THE best of the bests I have ever came across to 🙂 This will definitely mark a niche in yhe skincare Industry as the results are beyond expected.  Must buy!!! ',
#  'THE best of the bests I have ever came across to 🙂 This will definitely mark a niche in yhe skincare Industry as the results are beyond expected.  Must buy!!! ',
#  'Loved the quality of this product. Not harsh on skin. Fragrance free. Worth it.',
#  "A new product I'm very happy with controls the oil and acne. The inner packaging is very cute!",
#  'Its a good cleanser and mild exfoliator. I am using it since 1 month. It reduces my acne breakout and also keep my skin oil free. Still using it for best result. I also use m...Read More']

# %%
len(rev_all)

# %%
len(tit)
# Out:
# 21

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df['title']=tit
df['review']=rev_all

# %%
df.head()
# Out:
#                           title  \
# 0  "Revolution in skin care!! "
# 1  "Revolution in skin care!! "
# 2   "Good for acne prone skin "
# 3                        "Good"
# 4                    "Worth it"
#
#                                               review
# 0  THE best of the bests I have ever came across ...
# 1  THE best of the bests I have ever came across ...
# 2  Loved the quality of this product. Not harsh o...
# 3  A new product I'm very happy with controls the...
# 4  Its a good cleanser and mild exfoliator. I am ...

# %%
import spacy
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import re
import unicodedata

# %%
df1=df.copy()
df1.head()
# Out:
#                           title  \
# 0  "Revolution in skin care!! "
# 1  "Revolution in skin care!! "
# 2   "Good for acne prone skin "
# 3                        "Good"
# 4                    "Worth it"
#
#                                               review
# 0  THE best of the bests I have ever came across ...
# 1  THE best of the bests I have ever came across ...
# 2  Loved the quality of this product. Not harsh o...
# 3  A new product I'm very happy with controls the...
# 4  Its a good cleanser and mild exfoliator. I am ...

# %% [markdown]
# # Removing accented characters and special characters

# %%
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text

# %%
df1['title']=df1['title'].apply(remove_accented_chars).apply(remove_special_characters)

# %%
df1['review']=df1['review'].apply(remove_accented_chars).apply(remove_special_characters)

# %%
df1.head()
# Out:
#                        title  \
# 0   Revolution in skin care
# 1   Revolution in skin care
# 2  Good for acne prone skin
# 3                       Good
# 4                   Worth it
#
#                                               review
# 0  THE best of the bests I have ever came across ...
# 1  THE best of the bests I have ever came across ...
# 2  Loved the quality of this product Not harsh on...
# 3  A new product Im very happy with controls the ...
# 4  Its a good cleanser and mild exfoliator I am u...

# %% [markdown]
# # Stemming into root words

# %%
def simple_stemmer(text):
    ps = nltk.porter.PorterStemmer()
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

# %%
df1['review']=df1['review'].apply(simple_stemmer)

# %%
df1['title']=df1['title'].apply(simple_stemmer)

# %%
df1.head()
# Out:
#                      title                                             review
# 0     revolut in skin care  the best of the best i have ever came across t...
# 1     revolut in skin care  the best of the best i have ever came across t...
# 2  good for acn prone skin  love the qualiti of thi product not harsh on s...
# 3                     good  a new product im veri happi with control the o...
# 4                 worth it  it a good cleanser and mild exfoli i am use it...

# %% [markdown]
# # Removing stop words

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ashwin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
stopword_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'nor',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
df1['review']=df1['review'].apply(remove_stopwords)

# %%
df1['title']=df1['title'].apply(remove_stopwords)

# %%
df1.head()
# Out:
#                  title                                             review
# 0    revolut skin care  best best ever came across thi definit mark ni...
# 1    revolut skin care  best best ever came across thi definit mark ni...
# 2  good acn prone skin  love qualiti thi product not harsh skin fragra...
# 3                 good  new product im veri happi control oil acn inne...
# 4                worth  good cleanser mild exfoli use sinc 1 month red...

# %% [markdown]
# # Sentiment analysis

# %%
from afinn import Afinn

# %%
af=Afinn()

# %%
sent_score=[af.score(x) for x in df1['review']]

# %%
sent_score
# Out:
# [6.0,
#  6.0,
#  4.0,
#  2.0,
#  7.0,
#  1.0,
#  4.0,
#  -1.0,
#  6.0,
#  -1.0,
#  6.0,
#  3.0,
#  7.0,
#  1.0,
#  3.0,
#  0.0,
#  3.0,
#  0.0,
#  4.0,
#  3.0,
#  6.0]

# %%
sentiment_category = ['positive' if score > 0 
                          else 'negative' if score < 0 
                              else 'neutral' 
                                  for score in sent_score]

# %%
sentiment_category
# Out:
# ['positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive']

# %%
df1['sent_score']=sent_score

# %%
df1['sent_cat']=sentiment_category

# %%
df1.head()
# Out:
#                  title                                             review  \
# 0    revolut skin care  best best ever came across thi definit mark ni...
# 1    revolut skin care  best best ever came across thi definit mark ni...
# 2  good acn prone skin  love qualiti thi product not harsh skin fragra...
# 3                 good  new product im veri happi control oil acn inne...
# 4                worth  good cleanser mild exfoli use sinc 1 month red...
#
#    sent_score  sent_cat
# 0         6.0  positive
# 1         6.0  positive
# 2         4.0  positive
# 3         2.0  positive
# 4         7.0  positive

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1['sent_cat'].value_counts()
# Out:
# positive    17
# negative     2
# neutral      2
# Name: sent_cat, dtype: int64

# %%
df1['sent_cat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # With infinite scrolling

# %%
! pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.8.0-py3-none-any.whl (6.3 MB)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\ashwin\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\ashwin\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ashwin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\ashwin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: idna in c:\users\ashwin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\users\ashwin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\ashwin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\ashwin\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ashwin\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.1.0 h11-0.14.0 outcome-1.2.0 selenium-4.8.0 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0

# %%
import time

# %%
from selenium import webdriver

driver = webdriver.Chrome()
driver.get('https://www.nykaa.com/minimalist-2percent-salicylic-acid-lha-face-cleanser-for-oil-control-acne/reviews/1467106?skuId=1467106&ptype=reviews')

scroll_pause_time = 2

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(scroll_pause_time)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
from bs4 import BeautifulSoup

# %%
soupp=BeautifulSoup(driver.page_source,'lxml')

# %%
headline_all=soupp.find_all('h4',class_='css-tm4hnq')

# %%
tit_all=[]
for x in headline_all:
    a=x.text
    tit_all.append(a)

# %%
tit_all[:5]
# Out:
# ['"Revolution in skin care!! "',
#  '"Revolution in skin care!! "',
#  '"Good for acne prone skin "',
#  '"Good"',
#  '"Worth it"']

# %%
reviews_all=soupp.find_all('p',class_='css-1n0nrdk')
reviews_all[:5]
# Out:
# [<p class="css-1n0nrdk">THE best of the bests I have ever came across to 🙂 This will definitely mark a niche in yhe skincare Industry as the results are beyond expected.  Must buy!!! </p>,
#  <p class="css-1n0nrdk">THE best of the bests I have ever came across to 🙂 This will definitely mark a niche in yhe skincare Industry as the results are beyond expected.  Must buy!!! </p>,
#  <p class="css-1n0nrdk">Loved the quality of this product. Not harsh on skin. Fragrance free. Worth it.</p>,
#  <p class="css-1n0nrdk">A new product I'm very happy with controls the oil and acne. The inner packaging is very cute!</p>,
#  <p class="css-1n0nrdk">Its a good cleanser and mild exfoliator. I am using it since 1 month. It reduces my acne breakout and also keep my skin oil free. Still using it for best result. I also use m<strong>...Read More</strong></p>]

# %%
rev_all=[]
for y in reviews_all:
    b=y.text
    rev_all.append(b)

# %%
rev_all[:5]
# Out:
# ['THE best of the bests I have ever came across to 🙂 This will definitely mark a niche in yhe skincare Industry as the results are beyond expected.  Must buy!!! ',
#  'THE best of the bests I have ever came across to 🙂 This will definitely mark a niche in yhe skincare Industry as the results are beyond expected.  Must buy!!! ',
#  'Loved the quality of this product. Not harsh on skin. Fragrance free. Worth it.',
#  "A new product I'm very happy with controls the oil and acne. The inner packaging is very cute!",
#  'Its a good cleanser and mild exfoliator. I am using it since 1 month. It reduces my acne breakout and also keep my skin oil free. Still using it for best result. I also use m...Read More']

# %%
len(rev_all)
# Out:
# 61

# %%
import pandas as pd

# %%
df_all=pd.DataFrame()

# %%
df_all['title']=tit_all

# %%
df_all['reviews']=rev_all

# %%
df_all.head()
# Out:
#                           title  \
# 0  "Revolution in skin care!! "
# 1  "Revolution in skin care!! "
# 2   "Good for acne prone skin "
# 3                        "Good"
# 4                    "Worth it"
#
#                                              reviews
# 0  THE best of the bests I have ever came across ...
# 1  THE best of the bests I have ever came across ...
# 2  Loved the quality of this product. Not harsh o...
# 3  A new product I'm very happy with controls the...
# 4  Its a good cleanser and mild exfoliator. I am ...

# %%
df_all.shape
# Out:
# (61, 2)

# %%
import spacy
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import re
import unicodedata

# %% [markdown]
# # Removing unwanted special characters and accented texts

# %%
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text

# %%
df_all['title']=df_all['title'].apply(remove_accented_chars).apply(remove_special_characters)
df_all['reviews']=df_all['reviews'].apply(remove_accented_chars).apply(remove_special_characters)
df_all.head()
# Out:
#                        title  \
# 0   Revolution in skin care
# 1   Revolution in skin care
# 2  Good for acne prone skin
# 3                       Good
# 4                   Worth it
#
#                                              reviews
# 0  THE best of the bests I have ever came across ...
# 1  THE best of the bests I have ever came across ...
# 2  Loved the quality of this product Not harsh on...
# 3  A new product Im very happy with controls the ...
# 4  Its a good cleanser and mild exfoliator I am u...

# %% [markdown]
# # Stemming

# %%
def simple_stemmer(text):
    ps = nltk.porter.PorterStemmer()
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

# %%
df_all['title']=df_all['title'].apply(simple_stemmer)
df_all['reviews']=df_all['reviews'].apply(simple_stemmer)
df_all.head()
# Out:
#                      title                                            reviews
# 0     revolut in skin care  the best of the best i have ever came across t...
# 1     revolut in skin care  the best of the best i have ever came across t...
# 2  good for acn prone skin  love the qualiti of thi product not harsh on s...
# 3                     good  a new product im veri happi with control the o...
# 4                 worth it  it a good cleanser and mild exfoli i am use it...

# %% [markdown]
# # Remove stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ashwin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
df_all['title']=df_all['title'].apply(remove_stopwords)
df_all['reviews']=df_all['reviews'].apply(remove_stopwords)
df_all.head()
# Out:
#                  title                                            reviews
# 0    revolut skin care  best best ever came across thi definit mark ni...
# 1    revolut skin care  best best ever came across thi definit mark ni...
# 2  good acn prone skin  love qualiti thi product not harsh skin fragra...
# 3                 good  new product im veri happi control oil acn inne...
# 4                worth  good cleanser mild exfoli use sinc 1 month red...

# %% [markdown]
# # Sentiment analysis

# %%
from afinn import Afinn

# %%
afi=Afinn()

# %%
sent_score=[afi.score(x) for x in df_all['reviews']]

# %%
sent_score[:5]
# Out:
# [6.0, 6.0, 4.0, 2.0, 7.0]

# %%
sentiment_category = ['positive' if score > 0 
                          else 'negative' if score < 0 
                              else 'neutral' 
                                  for score in sent_score]

# %%
sentiment_category[:5]
# Out:
# ['positive', 'positive', 'positive', 'positive', 'positive']

# %%
df_all['sent_score']=sent_score
df_all['sent_cat']=sentiment_category

# %%
df_all.head()
# Out:
#                  title                                            reviews  \
# 0    revolut skin care  best best ever came across thi definit mark ni...
# 1    revolut skin care  best best ever came across thi definit mark ni...
# 2  good acn prone skin  love qualiti thi product not harsh skin fragra...
# 3                 good  new product im veri happi control oil acn inne...
# 4                worth  good cleanser mild exfoli use sinc 1 month red...
#
#    sent_score  sent_cat
# 0         6.0  positive
# 1         6.0  positive
# 2         4.0  positive
# 3         2.0  positive
# 4         7.0  positive

# %%
df_all['sent_cat'].value_counts()
# Out:
# positive    50
# neutral      8
# negative     3
# Name: sent_cat, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df_all['sent_cat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wc=WordCloud()
wc.generate(str(df_all['reviews']))
plt.figure(figsize=(20,10), facecolor='k')
plt.title("Most frequent words in Nykaa reviews", fontsize=40,color='white')
plt.imshow(wc)
plt.show()

# %%
wc=WordCloud()
wc.generate(str(df_all['title']))
plt.figure(figsize=(20,10), facecolor='k')
plt.title("Most frequent words in Nykaa review title", fontsize=40,color='white')
plt.imshow(wc)
plt.show()
